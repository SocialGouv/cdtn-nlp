# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForQuestionAnswering

tokenizer = AutoTokenizer.from_pretrained("timpal0l/mdeberta-v3-base-squad2")
model = AutoModelForQuestionAnswering.from_pretrained("timpal0l/mdeberta-v3-base-squad2")
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# Downloading added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/879 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]

# %%
from transformers import pipeline

pipe = pipeline("question-answering", model="timpal0l/mdeberta-v3-base-squad2")

# %%
QA_input = {
    'question': "j'ai été en arrêt de travail pendant 45 jours, dois-je faire une visite médicale avant de reprendre ?",
    'context': "dans le cas d'une maladie ayant entraîné un arrêt d'au moins 50 jours, la visite médicale de reprise du travail est obligatoire",
}

pipe(QA_input)
# Out:
# {'score': 0.025792747735977173,
#  'start': 70,
#  'end': 127,
#  'answer': ' la visite médicale de reprise du travail est obligatoire'}

# %%
#%%capture cap --no-stderr

#for i in range(len(questions)):
for i in range(2):
    search(questions[i])
    print("/////////////////////////\n\n")


#with open('/home/remi/Desktop/output-xp', 'w+') as f:
#    f.write(cap.stdout)
# Out:
# je suis tombé malade pendant mes congés, est-ce que mes congés peuvent être repoussés ?
# <style type="text/css">
# #T_acd25_row0_col0, #T_acd25_row0_col1, #T_acd25_row0_col2, #T_acd25_row1_col0, #T_acd25_row1_col1, #T_acd25_row1_col2, #T_acd25_row2_col0, #T_acd25_row2_col1, #T_acd25_row2_col2, #T_acd25_row3_col0, #T_acd25_row3_col1, #T_acd25_row3_col2, #T_acd25_row4_col0, #T_acd25_row4_col1, #T_acd25_row4_col2, #T_acd25_row5_col0, #T_acd25_row5_col1, #T_acd25_row5_col2, #T_acd25_row6_col0, #T_acd25_row6_col1, #T_acd25_row6_col2 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_acd25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acd25_level0_col0" class="col_heading level0 col0" >source</th>
#       <th id="T_acd25_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_acd25_level0_col2" class="col_heading level0 col2" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acd25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acd25_row0_col0" class="data row0 col0" >fiches_service_public</td>
#       <td id="T_acd25_row0_col1" class="data row0 col1" >Peut-on prendre directement des congés après un arrêt maladie ?</td>
#       <td id="T_acd25_row0_col2" class="data row0 col2" >oui, vous pouvez prendre vos congés directement à la suite d'une période de maladie. vous n'avez pas à reprendre votre activité professionnelle une journée à la fin de votre arrêt de travail pour partir en congés. cependant, vous devez respecter les dates de départ en congé fixées par votre employeur avant votre arrêt de travail. exemple si votre arrêt de travail prend fin le jour précédent la date prévue de votre départ en congés, vous pouvez alors prendre directement vos congés.</td>
#     </tr>
#     <tr>
#       <th id="T_acd25_level0_row1" class="row_heading level0 row1" >742</th>
#       <td id="T_acd25_row1_col0" class="data row1 col0" >fiches_service_public</td>
#       <td id="T_acd25_row1_col1" class="data row1 col1" >Arrêt maladie et congés payés annuels</td>
#       <td id="T_acd25_row1_col2" class="data row1 col2" >établi avant les congés si vous êtes malade (maladie non-professionnelle, maladie professionnelle ou accident du travail ) avant votre départ prévu en congé, vous avez droit au report de vos congés payés après la date de reprise du travail à la suite de votre maladie. les congés payés acquis non pris ne sont donc pas perdus. votre employeur doit vous accorder une nouvelle période de congés, que ce soit durant la période de prise de congés en cours dans l'entreprise ou au-delà. à noter si votre employeur refuse de reporter les congés payés que vous avez acquis, mais pas pris en raison d'un arrêt de travail, il devra vous verser des dommages-intérêts en réparation du préjudice subi. à noter en cas de rupture de votre contrat de travail, vous avez droit à une indemnité compensatrice des congés payés acquis non pris.</td>
#     </tr>
#     <tr>
#       <th id="T_acd25_level0_row2" class="row_heading level0 row2" >740</th>
#       <td id="T_acd25_row2_col0" class="data row2 col0" >fiches_service_public</td>
#       <td id="T_acd25_row2_col1" class="data row2 col1" >Arrêt maladie et congés payés annuels</td>
#       <td id="T_acd25_row2_col2" class="data row2 col2" >que se passe-t-il si vous tombez malade pendant vos congés ou avant de prendre vos congés ? les conséquence sur vos congés varient selon la cause de votre arrêt de travail : maladie ordinaire, maladie professionnelle ou accident du travail. nous vous présentons les informations à connaître. maladie ordinaire arrêt établi pendant les congés si vous êtes en arrêt maladie pendant vos congés payés, votre employeur doit reporter vos jours de congés restants si la convention collective le prévoit. en l'absence de dispositions conventionnelles , le juge européen considère que le report des congés payés s'impose. cette position a été confirmée par la cour de cassation dans 3 arrêts rendus le 13 septembre 2023. si votre employeur ne vous accorde pas ce report, vous pouvez saisir le conseil de prud'hommes pour demander l'obtention de ce report. arrêt établi avant les congés si vous êtes malade (maladie non-professionnelle, maladie professionnelle ou accident du travail ) avant votre départ prévu en congé, vous avez droit au report de vos congés payés après la date de reprise du travail à la suite de votre maladie. les congés payés acquis non pris ne sont donc pas perdus. votre employeur doit vous accorder une nouvelle période de congés, que ce soit durant la période de prise de congés en cours dans l'entreprise ou au-delà. à noter si votre employeur refuse de reporter les congés payés que vous avez acquis, mais pas pris en raison d'un arrêt de travail, il devra vous verser des dommages-intérêts en réparation du préjudice subi. à noter en cas de rupture de votre contrat de travail, vous avez droit à une indemnité compensatrice des congés payés acquis non pris. maladie professionnelle arrêt établi pendant les congés si vous êtes en arrêt maladie pendant vos congés payés, votre employeur doit reporter vos</td>
#     </tr>
#     <tr>
#       <th id="T_acd25_level0_row3" class="row_heading level0 row3" >3997</th>
#       <td id="T_acd25_row3_col0" class="data row3 col0" >fiches_ministere_travail</td>
#       <td id="T_acd25_row3_col1" class="data row3 col1" >Les congés payés : quelle est l’incidence de l’absence pour maladie sur le droit aux congés payés ?</td>
#       <td id="T_acd25_row3_col2" class="data row3 col2" >les absences pour maladie (non professionnelle) n'ouvrent pas droit à des congés payés, sauf dispositions conventionnelles contraires. en revanche, l'employeur ne saurait déduire du congé annuel les jours d'absence pour maladie.</td>
#     </tr>
#     <tr>
#       <th id="T_acd25_level0_row4" class="row_heading level0 row4" >203</th>
#       <td id="T_acd25_row4_col0" class="data row4 col0" >fiches_service_public</td>
#       <td id="T_acd25_row4_col1" class="data row4 col1" >Salarié en arrêt maladie pendant un congé parental : quelles sont les règles ?</td>
#       <td id="T_acd25_row4_col2" class="data row4 col2" >pouvez-vous être indemnisé durant votre congé parental à temps plein ou à temps partiel si vous êtes en arrêt pour cause de maladie ? pouvez-vous bénéficier de droits aux remboursements des frais de santé en cas de maladie pendant votre congé parental ? nous vous expliquons les règles. temps plein il s'agit d'un arrêt maladie après la reprise du travail à la fin du congé parental vous bénéficiez des remboursements de frais de santé pour maladie pendant toute la durée de l'arrêt maladie. dans les 12 mois qui suivent la fin du congé parental, les indemnités journalières vous sont versées, en tenant compte des droits ouverts avant le départ en congé parental (ou en cas de congé de maternité). il s'agit d'un arrêt maladie sans reprise du travail à la fin du congé parental en cas d'impossibilité de reprendre le travail à cause d'une maladie à la fin du congé, les indemnités journalières et le remboursement des dépenses de santé vous sont versés pendant toute la durée de l'arrêt maladie. temps partiel il s'agit d'un arrêt maladie après la reprise du travail à la fin du congé parental si vous êtes en congé parental à temps partiel, vous bénéficiez de l'indemnité journalière pour maladie et du remboursement de ses dépenses de santé , dans les conditions habituelles, pendant toute la durée de l'arrêt maladie. il s'agit d'un arrêt maladie sans reprise du travail à la fin du congé parental en cas d'impossibilité de reprendre le travail à cause d'une maladie à la fin du congé, les indemnités journalières et le remboursement des dépenses de santé vous sont versés pendant toute la durée de l'arrêt maladie.</td>
#     </tr>
#     <tr>
#       <th id="T_acd25_level0_row5" class="row_heading level0 row5" >1079</th>
#       <td id="T_acd25_row5_col0" class="data row5 col0" >fiches_service_public</td>
#       <td id="T_acd25_row5_col1" class="data row5 col1" >Congés payés</td>
#       <td id="T_acd25_row5_col2" class="data row5 col2" >de la période légal
# /////////////////////////
#
#
# j'ai été en arrêt de travail pendant 45 jours, dois-je faire une visite médicale avant de reprendre ?
# <style type="text/css">
# #T_5817b_row0_col0, #T_5817b_row0_col1, #T_5817b_row0_col2, #T_5817b_row1_col0, #T_5817b_row1_col1, #T_5817b_row1_col2, #T_5817b_row2_col0, #T_5817b_row2_col1, #T_5817b_row2_col2, #T_5817b_row3_col0, #T_5817b_row3_col1, #T_5817b_row3_col2, #T_5817b_row4_col0, #T_5817b_row4_col1, #T_5817b_row4_col2, #T_5817b_row5_col0, #T_5817b_row5_col1, #T_5817b_row5_col2, #T_5817b_row6_col0, #T_5817b_row6_col1, #T_5817b_row6_col2 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_5817b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5817b_level0_col0" class="col_heading level0 col0" >source</th>
#       <th id="T_5817b_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_5817b_level0_col2" class="col_heading level0 col2" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5817b_level0_row0" class="row_heading level0 row0" >1188</th>
#       <td id="T_5817b_row0_col0" class="data row0 col0" >fiches_service_public</td>
#       <td id="T_5817b_row0_col1" class="data row0 col1" >Maladie professionnelle : reprise du travail du salarié</td>
#       <td id="T_5817b_row0_col2" class="data row0 col2" >vous vous demandez comment votre reprise du travail va s'effectuer à la suite de votre maladie professionnelle ? vous souhaitez savoir si vous allez être soumis ou non à une visite médicale ? nous vous communiquons les éléments à connaître. les informations diffèrent selon la durée de votre arrêt maladie : jusqu'à 3 mois ou plus de 3 mois. jusqu'à 3 mois quel est le but de la visite médicale de reprise du travail ? vous devez passer une visite de reprise du travail . elle doit avoir lieu, au plus tard dans les 8 jours qui suivent votre reprise du travail. elle se déroule devant le médecin du travail dont dépend votre entreprise. la visite de reprise du travail a pour objet les points suivants : vérifier que vous soyez apte à reprendre le travail vérifier si votre poste de travail (ou, si c'est le cas, le poste de reclassement auquel vous êtes affecté) est compatible avec votre état de santé examiner les propositions d'aménagement, d'adaptation du poste ou de reclassement faites par votre employeur à la suite des préconisations émises par le médecin du travail étudier l'aménagement, l'adaptation de votre poste ou votre reclassement émettre, si nécessaire, un avis d'inaptitude la visite de reprise du travail se déroule pendant les heures de travail . votre absence est rémunérée dans les conditions habituelles, c'est-à-dire comme du temps de travail effectif. si la visite de reprise du travail ne peut pas avoir lieu pendant les heures de travail (par exemple en cas de travail de nuit), le temps nécessaire aux examens médicaux est alors rémunéré comme du temps de travail effectif. dans quelles conditions reprenez-vous le travail ? lors de votre retour dans l'entreprise, vous reprenez votre précédent emploi. toutefois, si celui-ci n'est plus disponible, vous devez alors être réintégré</td>
#     </tr>
#     <tr>
#       <th id="T_5817b_level0_row1" class="row_heading level0 row1" >641</th>
#       <td id="T_5817b_row1_col0" class="data row1 col0" >fiches_service_public</td>
#       <td id="T_5817b_row1_col1" class="data row1 col1" >Accident du travail : reprise du travail du salarié</td>
#       <td id="T_5817b_row1_col2" class="data row1 col2" >vous êtes en arrêt de travail à la suite d'un accident de travail et vous vous apprêtez à reprendre votre activité professionnelle ? vous voulez savoir si vous devez passer une visite médicale ou si vous pouvez reprendre à temps partiel ? selon la durée de votre arrêt, vous pouvez être soumis ou non à une visite médicale. dans certains cas, votre médecin traitant peut également vous proposer une reprise de travail léger, qui est indemnisé sous conditions par la sécurité sociale. arrêt inférieur à 30 jours devez-vous passer une visite médicale à l'occasion de votre reprise du travail ? en principe, vous ne devez pas passer une visite médicale après votre arrêt de travail. ainsi, vous reprenez votre travail dans les conditions habituelles. toutefois, après votre reprise du travail, lors de votre visite médicale périodique ou à l'occasion d'une visite que vous avez sollicitée, le médecin du travail peut, s'il l'estime nécessaire, vous préconiser des mesures de prévention des risques professionnels. à noter la suspension de votre contrat prend fin à la date d'expiration de l'arrêt de travail. vous devez reprendre votre activité le jour qui suit la date mentionnée sur votre certificat d'arrêt de travail. pouvez-vous reprendre à temps partiel (appelé travail léger pour raison médicale) ? votre médecin traitant peut vous autoriser à reprendre un travail léger pour raison médicale. dans ce cas, il vous préconise une reprise du travail à temps partiel. il doit vous remplir le certificat médical et le certificat d'arrêt de travail pour accident du travail ou maladie professionnelle. certificat médical accident du travail - maladie professionnelle caisse nationale d'assurance maladie (cnam) à noter depuis le 7 mai 2022, une fusion des différents formulaires permettant de prescrire les arrêts de travail (maladie, maladie professionnelle, accident du travail, prolongation,...) a été opérée. les règles</td>
#     </tr>
#     <tr>
#       <th id="T_5817b_level0_row2" class="row_heading level0 row2" >643</th>
#       <td id="T_5817b_row2_col0" class="data row2 col0" >fiches_service_public</td>
#       <td id="T_5817b_row2_col1" class="data row2 col1" >Accident du travail : reprise du travail du salarié</td>
#       <td id="T_5817b_row2_col2" class="data row2 col2" >visite de reprise du travail . elle doit avoir lieu, au plus tard dans les 8 jours qui suivent votre reprise du travail. elle se déroule devant le médecin du travail dont dépend votre entreprise. la visite de reprise du travail a pour objet les points suivants : vérifier que vous soyez apte à reprendre le travail vérifier si votre poste de travail (ou, si c'est le cas, le poste de reclassement auquel vous êtes affecté) est compatible avec votre état de santé examiner les propositions d'aménagement, d'adaptation du poste ou de reclassement faites par votre employeur à la suite des préconisations émises par le médecin du travail étudier l'aménagement, l'adaptation de votre poste ou votre reclassement émettre, si nécessaire, un avis d'inaptitude la visite de reprise du travail se déroule pendant les heures de travail . votre absence est rémunérée dans les conditions habituelles, c'est-à-dire comme du temps de travail effectif. si la visite de reprise du travail ne peut pas avoir lieu pendant les heures de travail (par exemple en cas de travail de nuit), le temps nécessaire aux examens médicaux est alors rémunéré comme du temps de travail effectif. dans quelles conditions reprenez-vous le travail ? lors de votre retour dans l'entreprise, vous reprenez votre précédent emploi. toutefois, si celui-ci n'est plus disponible, vous devez alors être réintégré dans un emploi similaire (de même qualification ou niveau hiérarchique par exemple), avec une rémunération équivalente. le médecin du travail peut demander des aménagements sur votre poste. à noter la suspension de votre contrat de travail prend fin à la date de la visite de reprise du travail. si l'examen médical de reprise n'a pas lieu le jour même de la reprise du travail, le contrat reste suspendu jusqu'à la visite médicale de reprise. par exemple, si vous reprenez</td>
#     </tr>
#     <tr>
#       <th id="T_5817b_level0_row3" class="row_heading level0 row3" >143</th>
#       <td id="T_5817b_row3_col0" class="data row3 col0" >fiches_service_public</td>
#       <td id="T_5817b_row3_col1" class="data row3 col1" >Arrêt maladie : reprise du travail du salarié</td>
#       <td id="T_5817b_row3_col2" class="data row3 col2" >déroule devant le médecin du travail dont dépend votre entreprise. la visite de reprise du travail a pour objet les points suivants : vérifier que vous êtes apte
# /////////////////////////

# %%
import spacy
#import fr_dep_news_trf
import spacy_transformers

#nlp = fr_dep_news_trf.load()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 3
#       1 import spacy
#       2 #import fr_dep_news_trf
# ----> 3 import spacy_transformers
#       5 #nlp = fr_dep_news_trf.load()
#
# File ~/.local/lib/python3.10/site-packages/spacy_transformers/__init__.py:1
# ----> 1 from . import architectures
#       2 from . import annotation_setters
#       3 from . import span_getters
#
# File ~/.local/lib/python3.10/site-packages/spacy_transformers/architectures.py:6
#       3 from thinc.types import Ragged, Floats2d
#       4 from spacy.tokens import Doc
# ----> 6 from .layers import TransformerModel, TransformerListener
#       7 from .layers import trfs2arrays, split_trf_batch
#       8 from .util import registry
#
# File ~/.local/lib/python3.10/site-packages/spacy_transformers/layers/__init__.py:1
# ----> 1 from .listener import TransformerListener
#       2 from .transformer_model import TransformerModel
#       3 from .split_trf import split_trf_batch
#
# File ~/.local/lib/python3.10/site-packages/spacy_transformers/layers/listener.py:4
#       2 from thinc.api import Model
#       3 from spacy.tokens import Doc
# ----> 4 from ..data_classes import TransformerData
#       7 class TransformerListener(Model):
#       8     """A layer that gets fed its answers from an upstream connection,
#       9     for instance from a component earlier in the pipeline.
#      10     """
#
# File ~/.local/lib/python3.10/site-packages/spacy_transformers/data_classes.py:5
#       3 import torch
#       4 import numpy
# ----> 5 from transformers.tokenization_utils import BatchEncoding
#       6 from transformers.file_utils import ModelOutput
#       7 from thinc.types import Ragged, Floats2d, Floats3d, FloatsXd, Ints2d
#
# File ~/.local/lib/python3.10/site-packages/transformers/tokenization_utils.py:26
#      23 from collections import OrderedDict
#      24 from typing import Any, Dict, List, Optional, Tuple, Union, overload
# ---> 26 from .tokenization_utils_base import (
#      27     ENCODE_KWARGS_DOCSTRING,
#      28     ENCODE_PLUS_ADDITIONAL_KWARGS_DOCSTRING,
#      29     INIT_TOKENIZER_DOCSTRING,
#      30     AddedToken,
#      31     BatchEncoding,
#      32     EncodedInput,
#      33     EncodedInputPair,
#      34     PreTokenizedInput,
#      35     PreTokenizedInputPair,
#      36     PreTrainedTokenizerBase,
#      37     TextInput,
#      38     TextInputPair,
#      39     TruncationStrategy,
#      40 )
#      41 from .utils import PaddingStrategy, TensorType, add_end_docstrings, logging
#      44 logger = logging.get_logger(__name__)
#
# File ~/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:37
#      35 from . import __version__
#      36 from .dynamic_module_utils import custom_object_save
# ---> 37 from .utils import (
#      38     EntryNotFoundError,
#      39     ExplicitEnum,
#      40     PaddingStrategy,
#      41     PushToHubMixin,
#      42     RepositoryNotFoundError,
#      43     RevisionNotFoundError,
#      44     TensorType,
#      45     add_end_docstrings,
#      46     cached_path,
#      47     copy_func,
#      48     get_file_from_repo,
#      49     hf_bucket_url,
#      50     is_flax_available,
#      51     is_offline_mode,
#      52     is_remote_url,
#      53     is_tf_available,
#      54     is_tokenizers_available,
#      55     is_torch_available,
#      56     logging,
#      57     to_py_obj,
#      58     torch_required,
#      59 )
#      60 from .utils.generic import _is_jax, _is_numpy, _is_tensorflow, _is_torch, _is_torch_device
#      63 if TYPE_CHECKING:
#
# ImportError: cannot import name 'cached_path' from 'transformers.utils' (/home/remi/.local/lib/python3.10/site-packages/transformers/utils/__init__.py)

# %%
# !pip install spacy-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy-transformers in /home/remi/.local/lib/python3.10/site-packages (1.1.7)
# Requirement already satisfied: spacy<4.0.0,>=3.1.3 in /home/remi/.local/lib/python3.10/site-packages (from spacy-transformers) (3.2.6)
# Requirement already satisfied: torch>=1.6.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy-transformers) (2.1.0)
# Requirement already satisfied: transformers<4.21.0,>=3.4.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy-transformers) (4.20.1)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /home/remi/.local/lib/python3.10/site-packages (from spacy-transformers) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy-transformers) (2.4.8)
# Requirement already satisfied: pathy>=0.3.5 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.10.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.4.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (8.0.17)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.0.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.7.4.1 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (4.5.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (4.64.1)
# Requirement already satisfied: jinja2 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (6.4.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (59.6.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.7.11)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.31.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /home/remi/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (21.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (2.18.1)
# Requirement already satisfied: fsspec in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (12.1.105)
# Requirement already satisfied: networkx in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (3.1)
# Requirement already satisfied: triton==2.1.0 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (2.1.0)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (11.4.5.107)
# Requirement already satisfied: filelock in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (3.12.4)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=1.6.0->spacy-transformers) (1.9)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/remi/.local/lib/python3.10/site-packages (from torch>=1.6.0->spacy-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/remi/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->spacy-transformers) (12.2.140)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/remi/.local/lib/python3.10/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers) (0.12.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/remi/.local/lib/python3.10/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers) (0.17.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/remi/.local/lib/python3.10/site-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers) (2023.10.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (2020.6.20)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/remi/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (3.3.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.5.0,>=0.3.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.1)

# %%
nlp = spacy.load("fr_dep_news_trf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 nlp = spacy.load("fr_dep_news_trf")
#
# File ~/.local/lib/python3.10/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      36     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      37 ) -> Language:
#      38     """Load a spaCy model from an installed package or a local path.
#      39
#      40     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:420, in load_model(name, vocab, disable, exclude, config)
#     418     return get_lang_class(name.replace("blank:", ""))()
#     419 if is_package(name):  # installed as package
# --> 420     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     421 if Path(name).exists():  # path to model data directory
#     422     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:453, in load_model_from_package(name, vocab, disable, exclude, config)
#     438 """Load a model from an installed package.
#     439
#     440 name (str): The package name.
#    (...)
#     450 RETURNS (Language): The loaded nlp object.
#     451 """
#     452 cls = importlib.import_module(name)
# --> 453 return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)
#
# File ~/.local/lib/python3.10/site-packages/fr_dep_news_trf/__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:615, in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     613 if not model_path.exists():
#     614     raise IOError(Errors.E052.format(path=data_path))
# --> 615 return load_model_from_path(
#     616     data_path,
#     617     vocab=vocab,
#     618     meta=meta,
#     619     disable=disable,
#     620     exclude=exclude,
#     621     config=config,
#     622 )
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:488, in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     486 overrides = dict_to_dot(config)
#     487 config = load_config(config_path, overrides=overrides)
# --> 488 nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
#     489 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:525, in load_model_from_config(config, vocab, disable, exclude, auto_fill, validate)
#     522 # This will automatically handle all codes registered via the languages
#     523 # registry, including custom subclasses provided via entry points
#     524 lang_cls = get_lang_class(nlp_config["lang"])
# --> 525 nlp = lang_cls.from_config(
#     526     config,
#     527     vocab=vocab,
#     528     disable=disable,
#     529     exclude=exclude,
#     530     auto_fill=auto_fill,
#     531     validate=validate,
#     532 )
#     533 return nlp
#
# File ~/.local/lib/python3.10/site-packages/spacy/language.py:1782, in Language.from_config(cls, config, vocab, disable, exclude, meta, auto_fill, validate)
#    1779     factory = pipe_cfg.pop("factory")
#    1780     # The pipe name (key in the config) here is the unique name
#    1781     # of the component, not necessarily the factory
# -> 1782     nlp.add_pipe(
#    1783         factory,
#    1784         name=pipe_name,
#    1785         config=pipe_cfg,
#    1786         validate=validate,
#    1787         raw_config=raw_config,
#    1788     )
#    1789 else:
#    1790     # We need the sourced components to reference the same
#    1791     # vocab without modifying the current vocab state **AND**
#    (...)
#    1796     # during deserialization, so they do not need any
#    1797     # additional handling.
#    1798     if vocab_b is None:
#
# File ~/.local/lib/python3.10/site-packages/spacy/language.py:792, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     784     if not self.has_factory(factory_name):
#     785         err = Errors.E002.format(
#     786             name=factory_name,
#     787             opts=", ".join(self.factory_names),
#    (...)
#     790             lang_code=self.lang,
#     791         )
# --> 792     pipe_component = self.create_pipe(
#     793         factory_name,
#     794         name=name,
#     795         config=config,
#     796         raw_config=raw_config,
#     797         validate=validate,
#     798     )
#     799 pipe_index = self._get_pipe_index(before, after, first, last)
#     800 self._pipe_meta[name] = self.get_factory_meta(factory_name)
#
# File ~/.local/lib/python3.10/site-packages/spacy/language.py:655, in Language.create_pipe(self, factory_name, name, config, raw_config, validate)
#     647 if not self.has_factory(factory_name):
#     648     err = Errors.E002.format(
#     649         name=factory_name,
#     650         opts=", ".join(self.factory_names),
#    (...)
#     653         lang_code=self.lang,
#     654     )
# --> 655     raise ValueError(err)
#     656 pipe_meta = self.get_factory_meta(factory_name)
#     657 # This is unideal, but the alternative would mean you always need to
#     658 # specify the full config settings, which is not really viable.
#
# ValueError: [E002] Can't find factory for 'transformer' for language French (fr). This usually happens when spaCy calls `nlp.create_pipe` with a custom component name that's not registered on the current language class. If you're using a Transformer, make sure to install 'spacy-transformers'. If you're using a custom component, make sure you've added the decorator `@Language.component` (for function components) or `@Language.factory` (for class components).
#
# Available factories: attribute_ruler, tok2vec, merge_noun_chunks, merge_entities, merge_subtokens, token_splitter, doc_cleaner, parser, beam_parser, entity_linker, ner, beam_ner, entity_ruler, lemmatizer, tagger, morphologizer, senter, sentencizer, textcat, spancat, textcat_multilabel, fr.lemmatizer

# %%
doc = nlp("L’employeur a l’obligation de prendre en charge une partie du prix des titres d’abonnement souscrits par ses salariés pour leurs déplacements entre leur résidence habituelle et leur lieu de travail accomplis au moyen de transports publics de personnes ou de services publics de location de vélos (art. L. 3261-2 du code du travail). – Le fait pour l’employeur de méconnaître les dispositions des articles L. 3261-1 à L. 3261-4 du Code du travail relatifs à la prise en charge des frais de transport est puni de l’amende prévue pour les contraventions de la 4ème classe. – Les dispositions du code du travail relatives à la prise en charge des frais de transport s’appliquent également aux stagiaires et, dans les conditions et selon les modalités prévues par le décret n° 2010-676 du 21 juin 2010 aux magistrats et aux personnels civils et militaires de l’État, des collectivités territoriales et de leurs établissements publics et aux autres agents publics mentionnés par ce décret. Les salariés bénéficiairesPour bénéficier de la prise en charge de leurs frais de transport, les salariés doivent remplir les deux conditions suivantes : utiliser des transports en commun ou un service public de locations de vélos (du type « Vélib’ » à Paris) pour aller de leur résidence habituelle à leur lieu de travail ; acheter, pour payer ces transports ou services, des titres d’abonnement figurant dans l’une ou l’autre des catégories mentionnées ci-dessous. L’employeur peut toutefois refuser la prise en charge lorsque le salarié perçoit déjà des indemnités représentatives de frais pour ses déplacements entre sa résidence habituelle et son ou ses lieux de travail d’un montant supérieur ou égal à la prise en charge de 50% visée ci-dessous.")
assert doc.has_annotation("SENT_START")
for sent in doc.sents:
    print(sent.text)

# %%
import stanza 
nlp = stanza.Pipeline(lang='fr', processors='tokenize', tokenize_no_ssplit=True)
doc = nlp("L’employeur a l’obligation de prendre en charge une partie du prix des titres d’abonnement souscrits par ses salariés pour leurs déplacements entre leur résidence habituelle et leur lieu de travail accomplis au moyen de transports publics de personnes ou de services publics de location de vélos (art. L. 3261-2 du code du travail). – Le fait pour l’employeur de méconnaître les dispositions des articles L. 3261-1 à L. 3261-4 du Code du travail relatifs à la prise en charge des frais de transport est puni de l’amende prévue pour les contraventions de la 4ème classe. – Les dispositions du code du travail relatives à la prise en charge des frais de transport s’appliquent également aux stagiaires et, dans les conditions et selon les modalités prévues par le décret n° 2010-676 du 21 juin 2010 aux magistrats et aux personnels civils et militaires de l’État, des collectivités territoriales et de leurs établissements publics et aux autres agents publics mentionnés par ce décret. Les salariés bénéficiairesPour bénéficier de la prise en charge de leurs frais de transport, les salariés doivent remplir les deux conditions suivantes : utiliser des transports en commun ou un service public de locations de vélos (du type « Vélib’ » à Paris) pour aller de leur résidence habituelle à leur lieu de travail ; acheter, pour payer ces transports ou services, des titres d’abonnement figurant dans l’une ou l’autre des catégories mentionnées ci-dessous. L’employeur peut toutefois refuser la prise en charge lorsque le salarié perçoit déjà des indemnités représentatives de frais pour ses déplacements entre sa résidence habituelle et son ou ses lieux de travail d’un montant supérieur ou égal à la prise en charge de 50% visée ci-dessous.")
for i, sentence in enumerate(doc.sentences):
    print(f'====== Sentence {i+1} tokens =======')
    print(*[f'id: {token.id}\ttext: {token.text}' for token in sentence.tokens], sep='\n')
# Out:
# 2023-10-19 15:00:19 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json: 367kB [00:00, 18.6MB/s]
# 2023-10-19 15:00:19 WARNING: Language fr package default expects mwt, which has been added
# 2023-10-19 15:00:19 INFO: Loading these models for language: fr (French):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | mwt       | combined |
# ========================
#
# 2023-10-19 15:00:19 INFO: Using device: cpu
# 2023-10-19 15:00:19 INFO: Loading: tokenize
# 2023-10-19 15:00:19 INFO: Loading: mwt
# 2023-10-19 15:00:19 INFO: Done loading processors!
# ====== Sentence 1 tokens =======
# id: (1,)	text: L’
# id: (2,)	text: employeur
# id: (3,)	text: a
# id: (4,)	text: l’
# id: (5,)	text: obligation
# id: (6,)	text: de
# id: (7,)	text: prendre
# id: (8,)	text: en
# id: (9,)	text: charge
# id: (10,)	text: une
# id: (11,)	text: partie
# id: (12, 13)	text: du
# id: (14,)	text: prix
# id: (15, 16)	text: des
# id: (17,)	text: titres
# id: (18,)	text: d’
# id: (19,)	text: abonnement
# id: (20,)	text: souscrits
# id: (21,)	text: par
# id: (22,)	text: ses
# id: (23,)	text: salariés
# id: (24,)	text: pour
# id: (25,)	text: leurs
# id: (26,)	text: déplacements
# id: (27,)	text: entre
# id: (28,)	text: leur
# id: (29,)	text: résidence
# id: (30,)	text: habituelle
# id: (31,)	text: et
# id: (32,)	text: leur
# id: (33,)	text: lieu
# id: (34,)	text: de
# id: (35,)	text: travail
# id: (36,)	text: accomplis
# id: (37, 38)	text: au
# id: (39,)	text: moyen
# id: (40,)	text: de
# id: (41,)	text: transports
# id: (42,)	text: publics
# id: (43,)	text: de
# id: (44,)	text: personnes
# id: (45,)	text: ou
# id: (46,)	text: de
# id: (47,)	text: services
# id: (48,)	text: publics
# id: (49,)	text: de
# id: (50,)	text: location
# id: (51,)	text: de
# id: (52,)	text: vélos
# id: (53,)	text: (
# id: (54,)	text: art
# id: (55,)	text: .
# id: (56,)	text: L.
# id: (57,)	text: 3261-2
# id: (58, 59)	text: du
# id: (60,)	text: code
# id: (61, 62)	text: du
# id: (63,)	text: travail
# id: (64,)	text: )
# id: (65,)	text: .
# id: (66,)	text: –
# id: (67,)	text: Le
# id: (68,)	text: fait
# id: (69,)	text: pour
# id: (70,)	text: l’
# id: (71,)	text: employeur
# id: (72,)	text: de
# id: (73,)	text: méconnaître
# id: (74,)	text: les
# id: (75,)	text: dispositions
# id: (76, 77)	text: des
# id: (78,)	text: articles
# id: (79,)	text: L.
# id: (80,)	text: 3261-1
# id: (81,)	text: à
# id: (82,)	text: L.
# id: (83,)	text: 3261-4
# id: (84, 85)	text: du
# id: (86,)	text: Code
# id: (87, 88)	text: du
# id: (89,)	text: travail
# id: (90,)	text: relatifs
# id: (91,)	text: à
# id: (92,)	text: la
# id: (93,)	text: prise
# id: (94,)	text: en
# id: (95,)	text: charge
# id: (96, 97)	text: des
# id: (98,)	text: frais
# id: (99,)	text: de
# id: (100,)	text: transport
# id: (101,)	text: est
# id: (102,)	text: puni
# id: (103,)	text: de
# id: (104,)	text: l’
# id: (105,)	text: amende
# id: (106,)	text: prévue
# id: (107,)	text: pour
# id: (108,)	text: les
# id: (109,)	text: contraventions
# id: (110,)	text: de
# id: (111,)	text: la
# id: (112,)	text: 4ème
# id: (113,)	text: classe
# id: (114,)	text: .
# id: (115,)	text: –
# id: (116,)	text: Les
# id: (117,)	text: dispositions
# id: (118, 119)	text: du
# id: (120,)	text: code
# id: (121, 122)	text: du
# id: (123,)	text: travail
# id: (124,)	text: relatives
# id: (125,)	text: à
# id: (126,)	text: la
# id: (127,)	text: prise
# id: (128,)	text: en
# id: (129,)	text: charge
# id: (130, 131)	text: des
# id: (132,)	text: frais
# id: (133,)	text: de
# id: (134,)	text: transport
# id: (135,)	text: s’
# id: (136,)	text: appliquent
# id: (137,)	text: également
# id: (138, 139)	text: aux
# id: (140,)	text: stagiaires
# id: (141,)	text: et
# id: (142,)	text: ,
# id: (143,)	text: dans
# id: (144,)	text: les
# id: (145,)	text: conditions
# id: (146,)	text: et
# id: (147,)	text: selon
# id: (148,)	text: les
# id: (149,)	text: modalités
# id: (150,)	text: prévues
# id: (151,)	text: par
# id: (152,)	text: le
# id: (153,)	text: décret
# id: (154,)	text: n°
# id: (155,)	text: 2010-676
# id: (156, 157)	text: du
# id: (158,)	text: 21
# id: (159,)	text: juin
# id: (160,)	text: 2010
# id: (161, 162)	text: aux
# id: (163,)	text: magistrats
# id: (164,)	text: et
# id: (165, 166)	text: aux
# id: (167,)	text: personnels
# id: (168,)	text: civils
# id: (169,)	text: et
# id: (170,)	text: militaires
# id: (171,)	text: de
# id: (172,)	text: l’
# id: (173,)	text: État
# id: (174,)	text: ,
# id: (175,)	text: des
# id: (176,)	text: collectivités
# id: (177,)	text: territoriales
# id: (178,)	text: et
# id: (179,)	text: de
# id: (180,)	text: leurs
# id: (181,)	text: établissements
# id: (182,)	text: publics
# id: (183,)	text: et
# id: (184, 185)	text: aux
# id: (186,)	text: autres
# id: (187,)	text: agents
# id: (188,)	text: publics
# id: (189,)	text: mentionnés
# id: (190,)	text: par
# id: (191,)	text: ce
# id: (192,)	text: décret
# id: (193,)	text: .
# id: (194,)	text: Les
# id: (195,)	text: salariés
# id: (196,)	text: bénéficiairesPour
# id: (197,)	text: bénéficier
# id: (198,)	text: de
# id: (199,)	text: la
# id: (200,)	text: prise
# id: (201,)	text: en
# id: (202,)	text: charge
# id: (203,)	text: de
# id: (204,)	text: leurs
# id: (205,)	text: frais
# id: (206,)	text: de
# id: (207,)	text: transport
# id: (208,)	text: ,
# id: (209,)	text: les
# id: (210,)	text: salariés
# id: (211,)	text: doivent
# id: (212,)	text: remplir
# id: (213,)	text: les
# id: (214,)	text: deux
# id: (215,)	text: conditions
# id: (216,)	text: suivantes
# id: (217,)	text: :
# id: (218,)	text: utiliser
# id: (219,)	text: des
# id: (220,)	text: transports
# id: (221,)	text: en
# id: (222,)	text: commun
# id: (223,)	text: ou
# id: (224,)	text: un
# id: (225,)	text: service
# id: (226,)	text: public
# id: (227,)	text: de
# id: (228,)	text: locations
# id: (229,)	text: de
# id: (230,)	text: vélos
# id: (231,)	text: (
# id: (232, 233)	text: du
# id: (234,)	text: type
# id: (235,)	text: «
# id: (236,)	text: Vélib’
# id: (237,)	text: »
# id: (238,)	text: à
# id: (239,)	text: Paris
# id: (240,)	text: )
# id: (241,)	text: pour
# id: (242,)	text: aller
# id: (243,)	text: de
# id: (244,)	text: leur
# id: (245,)	text: résidence
# id: (246,)	text: habituelle
# id: (247,)	text: à
# id: (248,)	text: leur
# id: (249,)	text: lieu
# id: (250,)	text: de
# id: (251,)	text: travail
# id: (252,)	text: ;
# id: (253,)	text: acheter
# id: (254,)	text: ,
# id: (255,)	text: pour
# id: (256,)	text: payer
# id: (257,)	text: ces
# id: (258,)	text: transports
# id: (259,)	text: ou
# id: (260,)	text: services
# id: (261,)	text: ,
# id: (262,)	text: des
# id: (263,)	text: titres
# id: (264,)	text: d’
# id: (265,)	text: abonnement
# id: (266,)	text: figurant
# id: (267,)	text: dans
# id: (268,)	text: l’
# id: (269,)	text: une
# id: (270,)	text: ou
# id: (271,)	text: l’
# id: (272,)	text: autre
# id: (273, 274)	text: des
# id: (275,)	text: catégories
# id: (276,)	text: mentionnées
# id: (277,)	text: ci-dessous
# id: (278,)	text: .
# id: (279,)	text: L’
# id: (280,)	text: employeur
# id: (281,)	text: peut
# id: (282,)	text: toutefois
# id: (283,)	text: refuser
# id: (284,)	text: la
# id: (285,)	text: prise
# id: (286,)	text: en
# id: (287,)	text: charge
# id: (288,)	text: lorsque
# id: (289,)	text: le
# id: (290,)	text: salarié
# id: (291,)	text: perçoit
# id: (292,)	text: déjà
# id: (293,)	text: des
# id: (294,)	text: indemnités
# id: (295,)	text: représentatives
# id: (296,)	text: de
# id: (297,)	text: frais
# id: (298,)	text: pour
# id: (299,)	text: ses
# id: (300,)	text: déplacements
# id: (301,)	text: entre
# id: (302,)	text: sa
# id: (303,)	text: résidence
# id: (304,)	text: habituelle
# id: (305,)	text: et
# id: (306,)	text: son
# id: (307,)	text: ou
# id: (308,)	text: ses
# id: (309,)	text: lieux
# id: (310,)	text: de
# id: (311,)	text: travail
# id: (312,)	text: d’
# id: (313,)	text: un
# id: (314,)	text: montant
# id: (315,)	text: supérieur
# id: (316,)	text: ou
# id: (317,)	text: égal
# id: (318,)	text: à
# id: (319,)	text: la
# id: (320,)	text: prise
# id: (321,)	text: en
# id: (322,)	text: charge
# id: (323,)	text: de
# id: (324,)	text: 50
# id: (325,)	text: %
# id: (326,)	text: visée
# id: (327,)	text: ci-dessous
# id: (328,)	text: .
